# %%
from DLC_xmazeSAtest_DataProcess import *

# %%
#please change this file path to the folder that containing the csv/h5 files(the track result of DLC)
filepathbase=r'D:\ADLAB\DLCdata0907\0720_18month_Track_DATA\Un_fitered'
csvlist=findallfile_csv(filepathbase)#the file list need to process

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
